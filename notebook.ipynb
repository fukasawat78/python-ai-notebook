# %% [markdown]
# # Mobile Price Classification(https://www.kaggle.com/iabhishekofficial/mobile-price-classification)
# ---

# %% [markdown]
# ## Setup & Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
# %config InlineBackend.figure_format = 'retina'

from src import *

np.set_printoptions(threshold=np.inf)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ## Data

# %%
#load and look at the data
DATASET_PATH = './datasets/mobile_price_classification'

train = pd.read_csv(DATASET_PATH + '/train.csv')
test = pd.read_csv(DATASET_PATH + '/test.csv')

train["type"] = "train"
test["type"] = "test"
df = pd.concat([train, test], axis=0)
df = df.drop(columns="id")

print(df.shape)

df.head()
# Out:
# (3000, 22)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range   type
# 0        0             0     1          1.0  train
# 1        1             1     0          2.0  train
# 2        1             1     0          2.0  train
# 3        1             0     0          2.0  train
# 4        1             1     0          1.0  train

# %%
config = {
    "num_col_names": [
        "battery_power", 
        "clock_speed", 
        "int_memory", 
        "m_dep",
        "mobile_wt", 
        "px_height",
        "px_width",
        "ram",
        "sc_h",
        "sc_w",
        "talk_time",
    ],
    "cat_col_names": [
        "blue", 
        "dual_sim", 
        "fc", 
        "four_g", 
        "n_cores", 
        "pc", 
        "three_g",
        "touch_screen",
        "wifi",
    ],
    "target": ["price_range"],
    "n_splits": 5,
    "shuffle": True,
    "SEED": 1234,
}

df[config["num_col_names"]] = df[config["num_col_names"]].astype("float")
df[config["cat_col_names"]] = df[config["cat_col_names"]].astype("category")
df[config["target"]] = df[config["target"]].astype("category")

# %% [markdown]
# ## Process missing values

# %%
df = categorical_imputer(
    df=df, 
    cat_col_names=config["cat_col_names"]
)
#df = drop_missing_data(df)
print(df.shape)
# Out:
# (3000, 22)
# /opt/conda/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:2631: FutureWarning: The `inplace` parameter in pandas.Categorical.add_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   res = method(*args, **kwargs)

# %% [markdown]
# ## Categorical encoding

# %%
df = rarelabel_encoder(
    df=df, 
    cat_col_names=config["cat_col_names"]
)
df = ordinal_encoder(
    df=df, 
    cat_col_names=config["cat_col_names"]
)
print(df.shape)
df.head()
# Out:
# (3000, 22)
# /opt/conda/lib/python3.7/site-packages/feature_engine/encoding/rare_label.py:164: UserWarning: The number of unique categories for variable blue is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   "considered frequent".format(var)
# /opt/conda/lib/python3.7/site-packages/feature_engine/encoding/rare_label.py:164: UserWarning: The number of unique categories for variable dual_sim is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   "considered frequent".format(var)
# /opt/conda/lib/python3.7/site-packages/feature_engine/encoding/rare_label.py:164: UserWarning: The number of unique categories for variable four_g is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   "considered frequent".format(var)
# /opt/conda/lib/python3.7/site-packages/feature_engine/encoding/rare_label.py:164: UserWarning: The number of unique categories for variable n_cores is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   "considered frequent".format(var)
# /opt/conda/lib/python3.7/site-packages/feature_engine/encoding/rare_label.py:164: UserWarning: The number of unique categories for variable three_g is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   "considered frequent".format(var)
# /opt/conda/lib/python3.7/site-packages/feature_engine/encoding/rare_label.py:164: UserWarning: The number of unique categories for variable touch_screen is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   "considered frequent".format(var)
# /opt/conda/lib/python3.7/site-packages/feature_engine/encoding/rare_label.py:164: UserWarning: The number of unique categories for variable wifi is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   "considered frequent".format(var)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0          842.0     0          2.2         0   0       0         7.0    0.6
# 1         1021.0     1          0.5         1   1       1        53.0    0.7
# 2          563.0     1          0.5         1   2       1        41.0    0.9
# 3          615.0     1          2.5         0   1       0        10.0    0.8
# 4         1821.0     1          1.2         0   2       1        44.0    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width     ram  sc_h  sc_w  talk_time  \
# 0      188.0        0   0       20.0     756.0  2549.0   9.0   7.0       19.0
# 1      136.0        1   0      905.0    1988.0  2631.0  17.0   3.0        7.0
# 2      145.0        2   0     1263.0    1716.0  2603.0  11.0   2.0        9.0
# 3      131.0        3   0     1216.0    1786.0  2769.0  16.0   8.0       11.0
# 4      141.0        0   0     1208.0    1212.0  1411.0   8.0   2.0       15.0
#
#    three_g  touch_screen  wifi price_range   type
# 0        0             0     0         1.0  train
# 1        1             1     1         2.0  train
# 2        1             1     1         2.0  train
# 3        1             0     1         2.0  train
# 4        1             1     1         1.0  train

# %% [markdown]
# ## Feature creation

# %%
#df = create_math_transforms(
#)

# %% [markdown]
# ## Numerical transformer

# %%
df = equal_freq_discretiser(
    df=df, 
    num_col_names=config["num_col_names"]
)
df = variable_transformer(
    df=df, 
    num_col_names=config["num_col_names"],
    variable_type="power_transformer"
)
print(df.shape)
df.head()
# Out:
# (3000, 44)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0          842.0     0          2.2         0   0       0         7.0    0.6
# 1         1021.0     1          0.5         1   1       1        53.0    0.7
# 2          563.0     1          0.5         1   2       1        41.0    0.9
# 3          615.0     1          2.5         0   1       0        10.0    0.8
# 4         1821.0     1          1.2         0   2       1        44.0    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width     ram  sc_h  sc_w  talk_time  \
# 0      188.0        0   0       20.0     756.0  2549.0   9.0   7.0       19.0
# 1      136.0        1   0      905.0    1988.0  2631.0  17.0   3.0        7.0
# 2      145.0        2   0     1263.0    1716.0  2603.0  11.0   2.0        9.0
# 3      131.0        3   0     1216.0    1786.0  2769.0  16.0   8.0       11.0
# 4      141.0        0   0     1208.0    1212.0  1411.0   8.0   2.0       15.0
#
#    three_g  touch_screen  wifi price_range   type  battery_power_disc  \
# 0        0             0     0         1.0  train                   2
# 1        1             1     1         2.0  train                   3
# 2        1             1     1         2.0  train                   0
# 3        1             0     1         2.0  train                   0
# 4        1             1     1         1.0  train                   8
#
#    clock_speed_disc  int_memory_disc  m_dep_disc  mobile_wt_disc  \
# 0                 5                0           4               8
# 1                 0                8           5               4
# 2                 0                6           7               5
# 3                 6                1           6               4
# 4                 1                6           4               5
#
#    px_height_disc  px_width_disc  ram_disc  sc_h_disc  sc_w_disc  \
# 0               0              1         6          2          5
# 1               7              9         6          7          1
# 2               8              8         6          3          1
# 3               8              8         6          7          5
# 4               8              4         3          1          1
#
#    talk_time_disc  battery_power_power_transformer  \
# 0               8                        29.017236
# 1               2                        31.953091
# 2               3                        23.727621
# 3               4                        24.799194
# 4               6                        42.673177
#
#    clock_speed_power_transformer  int_memory_power_transformer  \
# 0                       1.483240                      2.645751
# 1                       0.707107                      7.280110
# 2                       0.707107                      6.403124
# 3                       1.581139                      3.162278
# 4                       1.095445                      6.633250
#
#    m_dep_power_transformer  mobile_wt_power_transformer  \
# 0                 0.774597                    13.711309
# 1                 0.836660                    11.661904
# 2                 0.948683                    12.041595
# 3                 0.894427                    11.445523
# 4                 0.774597                    11.874342
#
#    px_height_power_transformer  px_width_power_transformer  \
# 0                     4.472136                   27.495454
# 1                    30.083218                   44.586994
# 2                    35.538711                   41.424630
# 3                    34.871192                   42.261093
# 4                    34.756294                   34.813790
#
#    ram_power_transformer  sc_h_power_transformer  sc_w_power_transformer  \
# 0              50.487622                3.000000                2.645751
# 1              51.293274                4.123106                1.732051
# 2              51.019604                3.316625                1.414214
# 3              52.621288                4.000000                2.828427
# 4              37.563280                2.828427                1.414214
#
#    talk_time_power_transformer
# 0                     4.358899
# 1                     2.645751
# 2                     3.000000
# 3                     3.316625
# 4                     3.872983

# %% [markdown]
# ## Outliers

# %%
df = censor_outliers(
    df=df, 
    num_col_names=config["num_col_names"]
)
print(df.shape)
df.head()
# Out:
# (3000, 44)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0          842.0     0          2.2         0   0       0         7.0    0.6
# 1         1021.0     1          0.5         1   1       1        53.0    0.7
# 2          563.0     1          0.5         1   2       1        41.0    0.9
# 3          615.0     1          2.5         0   1       0        10.0    0.8
# 4         1821.0     1          1.2         0   2       1        44.0    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width     ram  sc_h  sc_w  talk_time  \
# 0      188.0        0   0       20.0     756.0  2549.0   9.0   7.0       19.0
# 1      136.0        1   0      905.0    1988.0  2631.0  17.0   3.0        7.0
# 2      145.0        2   0     1263.0    1716.0  2603.0  11.0   2.0        9.0
# 3      131.0        3   0     1216.0    1786.0  2769.0  16.0   8.0       11.0
# 4      141.0        0   0     1208.0    1212.0  1411.0   8.0   2.0       15.0
#
#    three_g  touch_screen  wifi price_range   type  battery_power_disc  \
# 0        0             0     0         1.0  train                   2
# 1        1             1     1         2.0  train                   3
# 2        1             1     1         2.0  train                   0
# 3        1             0     1         2.0  train                   0
# 4        1             1     1         1.0  train                   8
#
#    clock_speed_disc  int_memory_disc  m_dep_disc  mobile_wt_disc  \
# 0                 5                0           4               8
# 1                 0                8           5               4
# 2                 0                6           7               5
# 3                 6                1           6               4
# 4                 1                6           4               5
#
#    px_height_disc  px_width_disc  ram_disc  sc_h_disc  sc_w_disc  \
# 0               0              1         6          2          5
# 1               7              9         6          7          1
# 2               8              8         6          3          1
# 3               8              8         6          7          5
# 4               8              4         3          1          1
#
#    talk_time_disc  battery_power_power_transformer  \
# 0               8                        29.017236
# 1               2                        31.953091
# 2               3                        23.727621
# 3               4                        24.799194
# 4               6                        42.673177
#
#    clock_speed_power_transformer  int_memory_power_transformer  \
# 0                       1.483240                      2.645751
# 1                       0.707107                      7.280110
# 2                       0.707107                      6.403124
# 3                       1.581139                      3.162278
# 4                       1.095445                      6.633250
#
#    m_dep_power_transformer  mobile_wt_power_transformer  \
# 0                 0.774597                    13.711309
# 1                 0.836660                    11.661904
# 2                 0.948683                    12.041595
# 3                 0.894427                    11.445523
# 4                 0.774597                    11.874342
#
#    px_height_power_transformer  px_width_power_transformer  \
# 0                     4.472136                   27.495454
# 1                    30.083218                   44.586994
# 2                    35.538711                   41.424630
# 3                    34.871192                   42.261093
# 4                    34.756294                   34.813790
#
#    ram_power_transformer  sc_h_power_transformer  sc_w_power_transformer  \
# 0              50.487622                3.000000                2.645751
# 1              51.293274                4.123106                1.732051
# 2              51.019604                3.316625                1.414214
# 3              52.621288                4.000000                2.828427
# 4              37.563280                2.828427                1.414214
#
#    talk_time_power_transformer
# 0                     4.358899
# 1                     2.645751
# 2                     3.000000
# 3                     3.316625
# 4                     3.872983

# %% [markdown]
# ## Drop Features

# %%
#df = drop_constant_features(df)
print(df.shape)
df.head()
# Out:
# (3000, 44)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0          842.0     0          2.2         0   0       0         7.0    0.6
# 1         1021.0     1          0.5         1   1       1        53.0    0.7
# 2          563.0     1          0.5         1   2       1        41.0    0.9
# 3          615.0     1          2.5         0   1       0        10.0    0.8
# 4         1821.0     1          1.2         0   2       1        44.0    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width     ram  sc_h  sc_w  talk_time  \
# 0      188.0        0   0       20.0     756.0  2549.0   9.0   7.0       19.0
# 1      136.0        1   0      905.0    1988.0  2631.0  17.0   3.0        7.0
# 2      145.0        2   0     1263.0    1716.0  2603.0  11.0   2.0        9.0
# 3      131.0        3   0     1216.0    1786.0  2769.0  16.0   8.0       11.0
# 4      141.0        0   0     1208.0    1212.0  1411.0   8.0   2.0       15.0
#
#    three_g  touch_screen  wifi price_range   type  battery_power_disc  \
# 0        0             0     0         1.0  train                   2
# 1        1             1     1         2.0  train                   3
# 2        1             1     1         2.0  train                   0
# 3        1             0     1         2.0  train                   0
# 4        1             1     1         1.0  train                   8
#
#    clock_speed_disc  int_memory_disc  m_dep_disc  mobile_wt_disc  \
# 0                 5                0           4               8
# 1                 0                8           5               4
# 2                 0                6           7               5
# 3                 6                1           6               4
# 4                 1                6           4               5
#
#    px_height_disc  px_width_disc  ram_disc  sc_h_disc  sc_w_disc  \
# 0               0              1         6          2          5
# 1               7              9         6          7          1
# 2               8              8         6          3          1
# 3               8              8         6          7          5
# 4               8              4         3          1          1
#
#    talk_time_disc  battery_power_power_transformer  \
# 0               8                        29.017236
# 1               2                        31.953091
# 2               3                        23.727621
# 3               4                        24.799194
# 4               6                        42.673177
#
#    clock_speed_power_transformer  int_memory_power_transformer  \
# 0                       1.483240                      2.645751
# 1                       0.707107                      7.280110
# 2                       0.707107                      6.403124
# 3                       1.581139                      3.162278
# 4                       1.095445                      6.633250
#
#    m_dep_power_transformer  mobile_wt_power_transformer  \
# 0                 0.774597                    13.711309
# 1                 0.836660                    11.661904
# 2                 0.948683                    12.041595
# 3                 0.894427                    11.445523
# 4                 0.774597                    11.874342
#
#    px_height_power_transformer  px_width_power_transformer  \
# 0                     4.472136                   27.495454
# 1                    30.083218                   44.586994
# 2                    35.538711                   41.424630
# 3                    34.871192                   42.261093
# 4                    34.756294                   34.813790
#
#    ram_power_transformer  sc_h_power_transformer  sc_w_power_transformer  \
# 0              50.487622                3.000000                2.645751
# 1              51.293274                4.123106                1.732051
# 2              51.019604                3.316625                1.414214
# 3              52.621288                4.000000                2.828427
# 4              37.563280                2.828427                1.414214
#
#    talk_time_power_transformer
# 0                     4.358899
# 1                     2.645751
# 2                     3.000000
# 3                     3.316625
# 4                     3.872983

# %% [markdown]
# ## Data split and target transformation

# %%
train, test = df[df["type"]=="train"].drop(columns="type"), df[df["type"]=="test"].drop(columns="type")

train = target_transformer(
    df=train, 
    target=config["target"], 
)
print(train.shape)

train, val, test = data_splitting(
    df=train,
    target=config["target"],
    n_splits=config["n_splits"],
    shuffle=config["shuffle"],
    random_state=config["SEED"]
)
print(train.shape, val.shape, test.shape)
# Out:
# (2000, 43)
# (1280, 43) (320, 43) (400, 43)

# %% [markdown]
# ## Training

# %%
import lightgbm as lgm

model = lgm.LGBMClassifier(
    max_depth=4,
    random_state=config["SEED"]
)

trainer = Trainer(
    model=model,
    target=config["target"],
    random_state=config["SEED"]
)

trainer.fit(train, val)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/lib/python3.7/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 1.21259
# [2]	valid_0's multi_logloss: 1.07937
# [3]	valid_0's multi_logloss: 0.975322
# [4]	valid_0's multi_logloss: 0.894108
# [5]	valid_0's multi_logloss: 0.824975
# [6]	valid_0's multi_logloss: 0.764833
# [7]	valid_0's multi_logloss: 0.718629
# [8]	valid_0's multi_logloss: 0.677307
# [9]	valid_0's multi_logloss: 0.642426
# [10]	valid_0's multi_logloss: 0.613323
# [11]	valid_0's multi_logloss: 0.587083
# [12]	valid_0's multi_logloss: 0.561068
# [13]	valid_0's multi_logloss: 0.539122
# [14]	valid_0's multi_logloss: 0.517833
# [15]	valid_0's multi_logloss: 0.494948
# [16]	valid_0's multi_logloss: 0.478798
# [17]	valid_0's multi_logloss: 0.465509
# [18]	valid_0's multi_logloss: 0.451839
# [19]	valid_0's multi_logloss: 0.438643
# [20]	valid_0's multi_logloss: 0.425598
# [21]	valid_0's multi_logloss: 0.413548
# [22]	valid_0's multi_logloss: 0.401813
# [23]	valid_0's multi_logloss: 0.39051
# [24]	valid_0's multi_logloss: 0.382542
# [25]	valid_0's multi_logloss: 0.375419
# [26]	valid_0's multi_logloss: 0.368872
# [27]	valid_0's multi_logloss: 0.362446
# [28]	valid_0's multi_logloss: 0.358781
# [29]	valid_0's multi_logloss: 0.353085
# [30]	valid_0's multi_logloss: 0.348179
# [31]	valid_0's multi_logloss: 0.341955
# [32]	valid_0's multi_logloss: 0.337304
# [33]	valid_0's multi_logloss: 0.335255
# [34]	valid_0's multi_logloss: 0.332618
# [35]	valid_0's multi_logloss: 0.330566
# [36]	valid_0's multi_logloss: 0.325819
# [37]	valid_0's multi_logloss: 0.32316
# [38]	valid_0's multi_logloss: 0.318638
# [39]	valid_0's multi_logloss: 0.315419
# [40]	valid_0's multi_logloss: 0.312609
# [41]	valid_0's multi_logloss: 0.310694
# [42]	valid_0's multi_logloss: 0.307545
# [43]	valid_0's multi_logloss: 0.306108
# [44]	valid_0's multi_logloss: 0.305108
# [45]	valid_0's multi_logloss: 0.302997
# [46]	valid_0's multi_logloss: 0.300332
# [47]	valid_0's multi_logloss: 0.299081
# [48]	valid_0's multi_logloss: 0.298617
# [49]	valid_0's multi_logloss: 0.295914
# [50]	valid_0's multi_logloss: 0.294315
# [51]	valid_0's multi_logloss: 0.293736
# [52]	valid_0's multi_logloss: 0.293745
# [53]	valid_0's multi_logloss: 0.293706
# [54]	valid_0's multi_logloss: 0.293277
# [55]	valid_0's multi_logloss: 0.292721
# [56]	valid_0's multi_logloss: 0.29201
# [57]	valid_0's multi_logloss: 0.289785
# [58]	valid_0's multi_logloss: 0.288115
# [59]	valid_0's multi_logloss: 0.285774
# [60]	valid_0's multi_logloss: 0.287405
# [61]	valid_0's multi_logloss: 0.285652
# [62]	valid_0's multi_logloss: 0.283224
# [63]	valid_0's multi_logloss: 0.28297
# [64]	valid_0's multi_logloss: 0.283997
# [65]	valid_0's multi_logloss: 0.283544
# [66]	valid_0's multi_logloss: 0.2824
# [67]	valid_0's multi_logloss: 0.28322
# [68]	valid_0's multi_logloss: 0.28052
# [69]	valid_0's multi_logloss: 0.280538
# [70]	valid_0's multi_logloss: 0.282253
# [71]	valid_0's multi_logloss: 0.280445
# [72]	valid_0's multi_logloss: 0.281455
# [73]	valid_0's multi_logloss: 0.280575
# [74]	valid_0's multi_logloss: 0.280803
# [75]	valid_0's multi_logloss: 0.282166
# [76]	valid_0's multi_logloss: 0.282189
# [77]	valid_0's multi_logloss: 0.283199
# [78]	valid_0's multi_logloss: 0.283744
# [79]	valid_0's multi_logloss: 0.284087
# [80]	valid_0's multi_logloss: 0.285185
# [81]	valid_0's multi_logloss: 0.283906
# [82]	valid_0's multi_logloss: 0.284378
# [83]	valid_0's multi_logloss: 0.283814
# [84]	valid_0's multi_logloss: 0.284192
# [85]	valid_0's multi_logloss: 0.284082
# [86]	valid_0's multi_logloss: 0.2842
# [87]	valid_0's multi_logloss: 0.283994
# [88]	valid_0's multi_logloss: 0.283264
# [89]	valid_0's multi_logloss: 0.283415
# [90]	valid_0's multi_logloss: 0.285156
# [91]	valid_0's multi_logloss: 0.286638
# [92]	valid_0's multi_logloss: 0.286095
# [93]	valid_0's multi_logloss: 0.285144
# [94]	valid_0's multi_logloss: 0.285338
# [95]	valid_0's multi_logloss: 0.285251
# [96]	valid_0's multi_logloss: 0.285772
# [97]	valid_0's multi_logloss: 0.285866
# [98]	valid_0's multi_logloss: 0.28747
# [99]	valid_0's multi_logloss: 0.287286
# [100]	valid_0's multi_logloss: 0.286677

# %% [markdown]
# ## Evaluation

# %%
trainer.evaluate(test)
# Out:
# confusion_matrix:
#  [[90  5  0  5]
#  [ 9 88  3  0]
#  [ 0  8 92  0]
#  [ 5  0  0 95]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       100
#            1       0.87      0.88      0.88       100
#            2       0.97      0.92      0.94       100
#            3       0.95      0.95      0.95       100
#
#     accuracy                           0.91       400
#    macro avg       0.91      0.91      0.91       400
# weighted avg       0.91      0.91      0.91       400
#
# AUC: 0.98875

# %% [markdown]
# ## Prediction

# %%
y_pred = trainer.predict(test.drop(columns=config["target"]))
